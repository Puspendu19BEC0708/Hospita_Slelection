# %% [markdown]
# # Introduction

# %% [markdown]
# ## Problem

# %% [markdown]
# Some Time when a person he / she does not know that place very well so it is very hard for him to find an hospital at the time of emergency some time person may get know the name of the hospital from another person but he does not know about the quality of that particular hospital so in this project we make hospital recomendation system where user will put the detail of the level of quality of hospital and as per his/her quality level we recomended hospital to him .
#
# Now by using ***Foursquare location*** this API is used to show the location of those recomended hospital in the world map

# %% [markdown]
# ## Background

# %% [markdown]
# Finding a hospital is different than to find a good hospital some time we are not able to find best hospital at the time of emergency in google map because in google map we can not provide some parameter such as Meets criteria for promoting interoperability of EHRs ,Mortality national comparison footnote,Safety of care national comparison footnote,Readmission national comparisonn etc so for that we created an project where we can use these feature to recomend a new hospital for our user

# %% [markdown]
# # Data

# %% [markdown]
# Here we are using the data set that contain the folloing things
# <li>
# Faculty Id
# <li>
# Facility Name
#     <li>
# Address
#  <li>
# City
#   <li>
# State
#    <li>
# ZIP Code
#        <li>
# County Name
#            <li>
# Phone Number
#                <li>
# Hospital Type
#                    <li>
# Hospital Ownership
#                        <li>
# Emergency Services
#                            <li>
# Meets criteria for promoting interoperability of EHRs
#                                <li>
# Hospital overall ratingn
#                                    <li>
# Hospital overall rating footnote
#                                        <li>
# Mortality national comparisonn
#                                            <li>
# Mortality national comparison footnote
#                                                <li>
# Safety of care national comparisonn
#                                                    <li>
# Safety of care national comparison footnote
#                                                        <li>
# Readmission national comparisonn
#                                                            <li>
# Readmission national comparison footnote
#                                                                <li>
# Patient experience national comparisonn
#                                                                    <li>
# Patient experience national comparison footnote
#                                                                        <li>
# Effectiveness of care national comparison footnoten
#                                                                            <li>
# Effectiveness of care national comparison footnoten
#                                                                                <li>
# Timeliness of care national comparisonn
#                                                                                    <li>
# Timeliness of care national comparison footnote
#                                                                                        <li>
# Efficient use of medical imaging national comparison footnote
#                                                                                            <li>
# Location
# <li>
# Among The above factor there some factor which decide the quality of the hospital among above features the feature which determine the quality of hospital is given below
#
# Emergency Services
#                            <li>
# Meets criteria for promoting interoperability of EHRs
#                                <li>
# Hospital overall ratingn
#                                    <li>
# Hospital overall rating footnote
#                                        <li>
# Mortality national comparisonn
#                                            <li>
# Mortality national comparison footnote
#                                                <li>
# Safety of care national comparisonn
#                                                    <li>
# Safety of care national comparison footnote
#                                                        <li>
# Readmission national comparisonn
#                                                            <li>
# Readmission national comparison footnote
#                                                                <li>
# Patient experience national comparisonn
#                                                                    <li>
# Patient experience national comparison footnote
#                                                                        <li>
# Effectiveness of care national comparison footnoten
#                                                                            <li>
# Effectiveness of care national comparison footnoten
#                                                                                <li>
# Timeliness of care national comparisonn
#                                                                                    <li>
# Timeliness of care national comparison footnote
#                                                                                        <li>
# Efficient use of medical imaging national comparison footnote
#                                                                                            <li>
# Location
#
# User have to provides thes data and among these data our recomender system will recomende the hospital suppose hospital recomendaded by our model is of Hospital Type Psychiatric then all the hospital of these type will be shown in the map by using ***Foursquare location*** t

# %% [markdown]
# # import libary

# %%
import pandas as pd
import os
import numpy as np 
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# #### Download the data set from my ibm storage which i store for this project

# %%
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_1 = {
    'IAM_SERVICE_ID': 'iam-ServiceId-b21f1762-43ac-4c08-b713-87cc313601ba',
    'IBM_API_KEY_ID': 'RxZH6HW3U6L9FJUUv4Z53BJeVVYdZ4yvYvPrX7tpEG0P',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.cloud.ibm.com/oidc/token',
    'BUCKET': 'hospitalselection-donotdelete-pr-qrw5w2z8u3gbmq',
    'FILE': 'Hospital_General_Information.csv'
}

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_8019663306054913a106f7ca1a38c7b3 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='RxZH6HW3U6L9FJUUv4Z53BJeVVYdZ4yvYvPrX7tpEG0P',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_8019663306054913a106f7ca1a38c7b3.get_object(Bucket='hospitalselection-donotdelete-pr-qrw5w2z8u3gbmq',Key='Hospital_General_Information.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#   Facility ID                            Facility Name  \
# 0       44022                 CONWAY BEHAVIORAL HEALTH
# 1       54154               SAN JOSE BEHAVIORAL HEALTH
# 2      121300         KAUAI VETERANS MEMORIAL HOSPITAL
# 3      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC
# 4      154060                         PARK CENTER, INC
#
#                         Address        City State  ZIP Code  County Name  \
# 0             2255 STURGIS ROAD      CONWAY    AR     72034     FAULKNER
# 1  455 SILICON VALLEY BOULEVARD    SAN JOSE    CA     95138  SANTA CLARA
# 2      4643 WAIMEA CANYON DRIVE      WAIMEA    HI     96796        KAUAI
# 3                  FERRELL ROAD   ROSICLARE    IL     62982       HARDIN
# 4             1909 CAREW STREET  FORT WAYNE    IN     46805        ALLEN
#
#    Phone Number              Hospital Type              Hospital Ownership  \
# 0  501 205-0011                Psychiatric                     Proprietary
# ...

# %% [markdown]
# #### Data preprocing that is cleaning of the data drop those table which are not required but before droping it stored it in your data set  in ibm cloud

# %%
df_data_1.drop('Mortality national comparisonn',axis=1,inplace=True)
df_data_1.drop('Safety of care national comparisonn',axis=1,inplace=True)
df_data_1.drop('Readmission national comparisonn',axis=1,inplace=True)
df_data_1.drop('Patient experience national comparisonn',axis=1,inplace=True)
df_data_1.drop('Effectiveness of care national comparison footnoten',axis=1,inplace=True)

# %%
#df_data_1.head()

# %%
df_data_1.drop('Timeliness of care national comparisonn',axis=1,inplace=True)

# %%
df_data_1.head()

# %%
#df_data_1.drop('Hospital overall ratingn',axis=1,inplace=True)

# %%
df_data_1.head()

# %%
df_data_1.head()
# Out:
#   Facility ID                            Facility Name  \
# 0       44022                 CONWAY BEHAVIORAL HEALTH
# 1       54154               SAN JOSE BEHAVIORAL HEALTH
# 2      121300         KAUAI VETERANS MEMORIAL HOSPITAL
# 3      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC
# 4      154060                         PARK CENTER, INC
#
#                         Address        City State  ZIP Code  County Name  \
# 0             2255 STURGIS ROAD      CONWAY    AR     72034     FAULKNER
# 1  455 SILICON VALLEY BOULEVARD    SAN JOSE    CA     95138  SANTA CLARA
# 2      4643 WAIMEA CANYON DRIVE      WAIMEA    HI     96796        KAUAI
# 3                  FERRELL ROAD   ROSICLARE    IL     62982       HARDIN
# 4             1909 CAREW STREET  FORT WAYNE    IN     46805        ALLEN
#
#    Phone Number              Hospital Type              Hospital Ownership  \
# 0  501 205-0011                Psychiatric                     Proprietary
# ...

# %% [markdown]
# #### drop nan value

# %%
df_data_1.dropna(subset=["Hospital Type"], axis=0, inplace=True)
df_data_1.dropna(subset=["Emergency Services"], axis=0, inplace=True)
df_data_1.dropna(subset=["Meets criteria for promoting interoperability of EHRs"], axis=0, inplace=True)
df_data_1.dropna(subset=["Hospital overall rating footnote"], axis=0, inplace=True)
df_data_1.dropna(subset=["Mortality national comparison footnote"], axis=0, inplace=True)
df_data_1.dropna(subset=["Safety of care national comparison footnote"], axis=0, inplace=True)
df_data_1.dropna(subset=["Readmission national comparison footnote"], axis=0, inplace=True)
df_data_1.dropna(subset=["Patient experience national comparison footnote"], axis=0, inplace=True)
df_data_1.dropna(subset=["Effectiveness of care national comparison footnoten.1"], axis=0, inplace=True)
df_data_1.dropna(subset=["Timeliness of care national comparison footnote"], axis=0, inplace=True)
df_data_1.dropna(subset=["Efficient use of medical imaging national comparison footnote"], axis=0, inplace=True)
df_data_1.dropna(subset=["Location"], axis=0, inplace=True)

# %%
df_data_1.reset_index(drop=True, inplace=True)

# %%
df_data_1.head()
# Out:
#   Facility ID                      Facility Name                 Address  \
# 0      271328              MARIAS MEDICAL CENTER            640 PARK AVE
# 1       51335     BEAR VALLEY COMMUNITY HOSPITAL        41870 GARSTIN DR
# 2       61343            KEEFE MEMORIAL HOSPITAL          602 N 6TH W ST
# 3      431307  SANFORD CLEAR LAKE MEDICAL CENTER  701 THIRD AVENUE SOUTH
# 4      381310  PIONEER MEMORIAL HOSPITAL HEPPNER     564 E PIONEER DRIVE
#
#              City State  ZIP Code     County Name  Phone Number  \
# 0          SHELBY    MT     59474           TOOLE  406 434-3200
# 1   BIG BEAR LAKE    CA     92315  SAN BERNARDINO  909 866-6501
# 2  CHEYENNE WELLS    CO     80810        CHEYENNE  719 767-5661
# 3      CLEAR LAKE    SD     57226           DEUEL  605 874-2141
# 4         HEPPNER    OR     97836          MORROW  541 676-9133
#
#                Hospital Type                           Hospital Ownership  \
# ...

# %% [markdown]
# #### convert categorical value into 0 and 1 here for yes i used 0 and for no i used 1

# %%
dummy=pd.get_dummies(df_data_1['Emergency Services'])
dummy
# Out:
#      No  Yes
# 0     0    1
# 1     1    0
# 2     0    1
# 3     0    1
# 4     0    1
# ..   ..  ...
# 112   0    1
# 113   1    0
# 114   0    1
# 115   0    1
# 116   0    1
#
# [117 rows x 2 columns]

# %%
df_data_2=pd.concat((df_data_1,dummy),axis=1)

# %%
df_data_2=df_data_2.drop(['Emergency Services'],axis=1)

# %%
df_data_2=df_data_2.drop(['Yes'],axis=1)

# %%
df_data_2=df_data_2.rename(columns={"No":"Emergency Services"})

# %%
df_data_2.drop('Meets criteria for promoting interoperability of EHRs',axis=1,inplace=True)

# %%
df_data_2
# Out:
#     Facility ID                      Facility Name  \
# 0        271328              MARIAS MEDICAL CENTER
# 1         51335     BEAR VALLEY COMMUNITY HOSPITAL
# 2         61343            KEEFE MEMORIAL HOSPITAL
# 3        431307  SANFORD CLEAR LAKE MEDICAL CENTER
# 4        381310  PIONEER MEMORIAL HOSPITAL HEPPNER
# ..          ...                                ...
# 112      451390           DIMMIT REGIONAL HOSPITAL
# 113      441300      SAINT THOMAS HICKMAN HOSPITAL
# 114      451351      LYNN COUNTY HOSPITAL DISTRICT
# 115      181332            FLEMING COUNTY HOSPITAL
# 116      670102              AD HOSPITAL EAST, LLC
#
#                            Address             City State  ZIP Code  \
# 0                     640 PARK AVE           SHELBY    MT     59474
# 1                 41870 GARSTIN DR    BIG BEAR LAKE    CA     92315
# 2                   602 N 6TH W ST   CHEYENNE WELLS    CO     80810
# 3           701 THIRD AVENUE SOUTH       CLEAR LAKE    SD     57226
# ...

# %% [markdown]
# #### make the hospital type coloumn in the the last which we have to predict accoring to the user quality level

# %%
title=list(df_data_2.columns)
title
# Out:
# ['Facility ID',
#  'Facility Name',
#  'Address',
#  'City',
#  'State',
#  'ZIP Code',
#  'County Name',
#  'Phone Number',
#  'Hospital Type',
#  'Hospital Ownership',
#  'Hospital overall rating footnote',
#  'Mortality national comparison footnote',
#  'Safety of care national comparison footnote',
#  'Readmission national comparison footnote',
#  'Patient experience national comparison footnote',
#  'Effectiveness of care national comparison footnoten.1',
#  'Timeliness of care national comparison footnote',
#  'Efficient use of medical imaging national comparison footnote',
#  'Location',
#  'Emergency Services']

# %%
title[0],title[10]=title[10],title[0]

# %%
df_data_2=df_data_2[title]

# %%
df_data_2
# Out:
#      Hospital overall rating footnote                      Facility Name  \
# 0                                16.0              MARIAS MEDICAL CENTER
# 1                                16.0     BEAR VALLEY COMMUNITY HOSPITAL
# 2                                16.0            KEEFE MEMORIAL HOSPITAL
# 3                                16.0  SANFORD CLEAR LAKE MEDICAL CENTER
# 4                                16.0  PIONEER MEMORIAL HOSPITAL HEPPNER
# ..                                ...                                ...
# 112                              16.0           DIMMIT REGIONAL HOSPITAL
# 113                              16.0      SAINT THOMAS HICKMAN HOSPITAL
# 114                              16.0      LYNN COUNTY HOSPITAL DISTRICT
# 115                               5.0            FLEMING COUNTY HOSPITAL
# 116                              16.0              AD HOSPITAL EAST, LLC
#
#                            Address             City State  ZIP Code  \
# ...

# %% [markdown]
# #### Enter the features set based on which my project recomend the type of hospital

# %%
X = df_data_2[['Emergency Services','Hospital overall rating footnote','Mortality national comparison footnote','Safety of care national comparison footnote','Readmission national comparison footnote','Patient experience national comparison footnote','Effectiveness of care national comparison footnoten.1','Timeliness of care national comparison footnote','Efficient use of medical imaging national comparison footnote']].values

# %%
X
# Out:
# array([[ 0., 16., 16., ...,  5.,  5., 16.],
#        [ 1., 16., 16., ...,  5.,  5., 16.],
#        [ 0., 16., 16., ..., 16.,  5., 16.],
#        ...,
#        [ 0., 16., 16., ..., 16., 16.,  5.],
#        [ 0.,  5.,  5., ...,  5.,  5.,  5.],
#        [ 0., 16., 16., ..., 16., 16., 16.]])

# %% [markdown]
# #### my target varivable which i want to predict

# %%
y = df_data_2["Hospital Type"]

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Divide data set into two part test and train to check our model acuracy

# %%
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
drugTree
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
drugTree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
predTree = drugTree.predict(X_testset)
predTree
# Out:
# array(['Critical Access Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
#        'Acute Care Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
#        'Acute Care Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
#        'Acute Care Hospitals', 'Critical Access Hospitals',
#        'Critical Access Hospitals', 'Critical Access Hospitals',
# ...

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree))
# Out:
# DecisionTrees's Accuracy:  0.9444444444444444

# %% [markdown]
# we get an acuaracy of 0.944 which is an good so we can proceed with our model

# %% [markdown]
# ##### user put the quality level that tell what type of model needed to use

# %%
XTEST=[[0,2,4,7,5,15,4,7,8]]

# %%
P=drugTree.predict(XTEST)
P[0]
# Out:
# 'Critical Access Hospitals'

# %% [markdown]
# now explore the adreeses of those hospital which have hospital type Critical Access Hospitals by exploring these addreses we came to know what are the best place to take food to take rest

# %% [markdown]
# #### before exploring the hospital let add those data which i have drop for prediction our hospital type

# %%
df_data_2
# Out:
#      Hospital overall rating footnote                      Facility Name  \
# 0                                16.0              MARIAS MEDICAL CENTER
# 1                                16.0     BEAR VALLEY COMMUNITY HOSPITAL
# 2                                16.0            KEEFE MEMORIAL HOSPITAL
# 3                                16.0  SANFORD CLEAR LAKE MEDICAL CENTER
# 4                                16.0  PIONEER MEMORIAL HOSPITAL HEPPNER
# ..                                ...                                ...
# 112                              16.0           DIMMIT REGIONAL HOSPITAL
# 113                              16.0      SAINT THOMAS HICKMAN HOSPITAL
# 114                              16.0      LYNN COUNTY HOSPITAL DISTRICT
# 115                               5.0            FLEMING COUNTY HOSPITAL
# 116                              16.0              AD HOSPITAL EAST, LLC
#
#                            Address             City State  ZIP Code  \
# ...

# %% [markdown]
# #### add the drop table

# %%
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_2 = {
    'IAM_SERVICE_ID': 'iam-ServiceId-b21f1762-43ac-4c08-b713-87cc313601ba',
    'IBM_API_KEY_ID': 'RxZH6HW3U6L9FJUUv4Z53BJeVVYdZ4yvYvPrX7tpEG0P',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.cloud.ibm.com/oidc/token',
    'BUCKET': 'hospitalselection-donotdelete-pr-qrw5w2z8u3gbmq',
    'FILE': 'drop table.csv'
}

# %%
body = client_8019663306054913a106f7ca1a38c7b3.get_object(Bucket='hospitalselection-donotdelete-pr-qrw5w2z8u3gbmq',Key='drop table.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_3 = pd.read_csv(body)
df_data_3.head()
# Out:
#                              Facility Name                       Address  \
# 0                 CONWAY BEHAVIORAL HEALTH             2255 STURGIS ROAD
# 1               SAN JOSE BEHAVIORAL HEALTH  455 SILICON VALLEY BOULEVARD
# 2         KAUAI VETERANS MEMORIAL HOSPITAL      4643 WAIMEA CANYON DRIVE
# 3  HARDIN COUNTY GENERAL HOSPITAL & CLINIC                  FERRELL ROAD
# 4                         PARK CENTER, INC             1909 CAREW STREET
#
#          City  County Name  Phone Number              Hospital Ownership  \
# 0      CONWAY     FAULKNER  501 205-0011                     Proprietary
# 1    SAN JOSE  SANTA CLARA  669 234-5959                     Proprietary
# 2      WAIMEA        KAUAI  808 338-9431              Government - State
# 3   ROSICLARE       HARDIN  618 285-6634  Voluntary non-profit - Private
# 4  FORT WAYNE        ALLEN  260 481-2700  Voluntary non-profit - Private
#
#                          Location
# 0                             NaN
# ...

# %%
df_data_3.dropna(subset=["Location"], axis=0, inplace=True)

# %% [markdown]
# #### merge with original one

# %%
df=pd.merge(df_data_3,df_data_2,on="Location")

# %%
df
# Out:
#                        Facility Name_x                      Address_x  \
# 0                MARIAS MEDICAL CENTER                   640 PARK AVE
# 1       BEAR VALLEY COMMUNITY HOSPITAL               41870 GARSTIN DR
# 2              KEEFE MEMORIAL HOSPITAL                 602 N 6TH W ST
# 3    SANFORD CLEAR LAKE MEDICAL CENTER         701 THIRD AVENUE SOUTH
# 4    PIONEER MEMORIAL HOSPITAL HEPPNER            564 E PIONEER DRIVE
# ..                                 ...                            ...
# 113           DIMMIT REGIONAL HOSPITAL             704 HOSPITAL DRIVE
# 114      SAINT THOMAS HICKMAN HOSPITAL           135 EAST SWAN STREET
# 115      LYNN COUNTY HOSPITAL DISTRICT           2600 LOCKWOOD STREET
# 116            FLEMING COUNTY HOSPITAL            55 FOUNDATION DRIVE
# 117              AD HOSPITAL EAST, LLC  12950 EAST FREEWAY, SUITE 100
#
#               City_x   County Name_x Phone Number_x  \
# 0             SHELBY           TOOLE   406 434-3200
# ...

# %%
df.drop('Facility Name_y',axis=1,inplace=True)
df.drop('Address_y',axis=1,inplace=True)
df.drop('City_y',axis=1,inplace=True)
df.drop('County Name_y',axis=1,inplace=True)
df.drop('Phone Number_y',axis=1,inplace=True)
df.drop('Hospital Ownership_y',axis=1,inplace=True)

# %%
df
# Out:
#                        Facility Name_x                      Address_x  \
# 0                MARIAS MEDICAL CENTER                   640 PARK AVE
# 1       BEAR VALLEY COMMUNITY HOSPITAL               41870 GARSTIN DR
# 2              KEEFE MEMORIAL HOSPITAL                 602 N 6TH W ST
# 3    SANFORD CLEAR LAKE MEDICAL CENTER         701 THIRD AVENUE SOUTH
# 4    PIONEER MEMORIAL HOSPITAL HEPPNER            564 E PIONEER DRIVE
# ..                                 ...                            ...
# 113           DIMMIT REGIONAL HOSPITAL             704 HOSPITAL DRIVE
# 114      SAINT THOMAS HICKMAN HOSPITAL           135 EAST SWAN STREET
# 115      LYNN COUNTY HOSPITAL DISTRICT           2600 LOCKWOOD STREET
# 116            FLEMING COUNTY HOSPITAL            55 FOUNDATION DRIVE
# 117              AD HOSPITAL EAST, LLC  12950 EAST FREEWAY, SUITE 100
#
#               City_x   County Name_x Phone Number_x  \
# 0             SHELBY           TOOLE   406 434-3200
# ...

# %% [markdown]
# #### Now add location data

# %%
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_3 = {
    'IAM_SERVICE_ID': 'iam-ServiceId-b21f1762-43ac-4c08-b713-87cc313601ba',
    'IBM_API_KEY_ID': 'RxZH6HW3U6L9FJUUv4Z53BJeVVYdZ4yvYvPrX7tpEG0P',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.cloud.ibm.com/oidc/token',
    'BUCKET': 'hospitalselection-donotdelete-pr-qrw5w2z8u3gbmq',
    'FILE': 'location data2.csv'
}

# %%
body = client_8019663306054913a106f7ca1a38c7b3.get_object(Bucket='hospitalselection-donotdelete-pr-qrw5w2z8u3gbmq',Key='location data2.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_4 = pd.read_csv(body)
df_data_4.head()
# Out:
#                          Location   Latitude   Longitude
# 0                             NaN         NaN        NaN
# 1   -121.77291599999998 37.246742 -121.772916  37.246742
# 2   -159.67005500000002 21.960079 -159.670055  21.960079
# 3                             NaN         NaN        NaN
# 4            -85.108024 41.093791  -85.108024  41.093791

# %%
df_data_4.dropna(subset=["Location"], axis=0, inplace=True)
df_data_4
# Out:
#                             Location   Latitude   Longitude
# 1      -121.77291599999998 37.246742 -121.772916  37.246742
# 2      -159.67005500000002 21.960079 -159.670055  21.960079
# 4               -85.108024 41.093791  -85.108024  41.093791
# 8               -94.101386 45.254576  -94.101386  45.254576
# 9               -71.154678 42.869242  -71.154678  42.869242
# ...                              ...         ...        ...
# 5309            -83.227413 37.279027  -83.227413  37.279027
# 5310            -84.293721 39.336786  -84.293721  39.336786
# 5311              -95.22854 30.04461  -95.228540  30.044610
# 5312            -80.254161 26.268779  -80.254161  26.268779
# 5313   -94.807751 39.776936000000006  -94.807751  39.776936
#
# [4910 rows x 3 columns]

# %%
df_data_4.reset_index(drop=True, inplace=True)
df_data_4
# Out:
#                             Location   Latitude   Longitude
# 0      -121.77291599999998 37.246742 -121.772916  37.246742
# 1      -159.67005500000002 21.960079 -159.670055  21.960079
# 2               -85.108024 41.093791  -85.108024  41.093791
# 3               -94.101386 45.254576  -94.101386  45.254576
# 4               -71.154678 42.869242  -71.154678  42.869242
# ...                              ...         ...        ...
# 4905            -83.227413 37.279027  -83.227413  37.279027
# 4906            -84.293721 39.336786  -84.293721  39.336786
# 4907              -95.22854 30.04461  -95.228540  30.044610
# 4908            -80.254161 26.268779  -80.254161  26.268779
# 4909   -94.807751 39.776936000000006  -94.807751  39.776936
#
# [4910 rows x 3 columns]

# %%
with_lat_long=df=pd.merge(df,df_data_4,on="Location")
with_lat_long
# Out:
#                        Facility Name_x                      Address_x  \
# 0                MARIAS MEDICAL CENTER                   640 PARK AVE
# 1       BEAR VALLEY COMMUNITY HOSPITAL               41870 GARSTIN DR
# 2              KEEFE MEMORIAL HOSPITAL                 602 N 6TH W ST
# 3    SANFORD CLEAR LAKE MEDICAL CENTER         701 THIRD AVENUE SOUTH
# 4    PIONEER MEMORIAL HOSPITAL HEPPNER            564 E PIONEER DRIVE
# ..                                 ...                            ...
# 119           DIMMIT REGIONAL HOSPITAL             704 HOSPITAL DRIVE
# 120      SAINT THOMAS HICKMAN HOSPITAL           135 EAST SWAN STREET
# 121      LYNN COUNTY HOSPITAL DISTRICT           2600 LOCKWOOD STREET
# 122            FLEMING COUNTY HOSPITAL            55 FOUNDATION DRIVE
# 123              AD HOSPITAL EAST, LLC  12950 EAST FREEWAY, SUITE 100
#
#               City_x   County Name_x Phone Number_x  \
# 0             SHELBY           TOOLE   406 434-3200
# ...

# %%
with_lat_long[["Latitude _x"]]
# Out:
#      Latitude _x
# 0    -111.850493
# 1    -116.888343
# 2    -102.355583
# 3     -96.682560
# 4    -119.547630
# ..           ...
# 119   -99.862098
# 120   -87.460242
# 121  -101.815507
# 122   -83.753094
# 123   -95.200782
#
# [124 rows x 1 columns]

# %%
with_lat_long.drop('Latitude _y',axis=1,inplace=True)
with_lat_long.drop('Longitude_y',axis=1,inplace=True)

# %%
with_lat_long
# Out:
#                        Facility Name_x                      Address_x  \
# 0                MARIAS MEDICAL CENTER                   640 PARK AVE
# 1       BEAR VALLEY COMMUNITY HOSPITAL               41870 GARSTIN DR
# 2              KEEFE MEMORIAL HOSPITAL                 602 N 6TH W ST
# 3    SANFORD CLEAR LAKE MEDICAL CENTER         701 THIRD AVENUE SOUTH
# 4    PIONEER MEMORIAL HOSPITAL HEPPNER            564 E PIONEER DRIVE
# ..                                 ...                            ...
# 119           DIMMIT REGIONAL HOSPITAL             704 HOSPITAL DRIVE
# 120      SAINT THOMAS HICKMAN HOSPITAL           135 EAST SWAN STREET
# 121      LYNN COUNTY HOSPITAL DISTRICT           2600 LOCKWOOD STREET
# 122            FLEMING COUNTY HOSPITAL            55 FOUNDATION DRIVE
# 123              AD HOSPITAL EAST, LLC  12950 EAST FREEWAY, SUITE 100
#
#               City_x   County Name_x Phone Number_x  \
# 0             SHELBY           TOOLE   406 434-3200
# ...

# %%
with_lat_long.rename(columns={'Latitude _x':'Latitude','Longitude_x':'Longitude'},inplace=True)
with_lat_long
# Out:
#                        Facility Name_x                      Address_x  \
# 0                MARIAS MEDICAL CENTER                   640 PARK AVE
# 1       BEAR VALLEY COMMUNITY HOSPITAL               41870 GARSTIN DR
# 2              KEEFE MEMORIAL HOSPITAL                 602 N 6TH W ST
# 3    SANFORD CLEAR LAKE MEDICAL CENTER         701 THIRD AVENUE SOUTH
# 4    PIONEER MEMORIAL HOSPITAL HEPPNER            564 E PIONEER DRIVE
# ..                                 ...                            ...
# 119           DIMMIT REGIONAL HOSPITAL             704 HOSPITAL DRIVE
# 120      SAINT THOMAS HICKMAN HOSPITAL           135 EAST SWAN STREET
# 121      LYNN COUNTY HOSPITAL DISTRICT           2600 LOCKWOOD STREET
# 122            FLEMING COUNTY HOSPITAL            55 FOUNDATION DRIVE
# 123              AD HOSPITAL EAST, LLC  12950 EAST FREEWAY, SUITE 100
#
#               City_x   County Name_x Phone Number_x  \
# 0             SHELBY           TOOLE   406 434-3200
# ...

# %%
with_lat_long.rename(columns={'County Name_x':'County_Name','Hospital Type':'Hospital_Type'},inplace=True)
with_lat_long
# Out:
#                        Facility Name_x                      Address_x  \
# 0                MARIAS MEDICAL CENTER                   640 PARK AVE
# 1       BEAR VALLEY COMMUNITY HOSPITAL               41870 GARSTIN DR
# 2              KEEFE MEMORIAL HOSPITAL                 602 N 6TH W ST
# 3    SANFORD CLEAR LAKE MEDICAL CENTER         701 THIRD AVENUE SOUTH
# 4    PIONEER MEMORIAL HOSPITAL HEPPNER            564 E PIONEER DRIVE
# ..                                 ...                            ...
# 119           DIMMIT REGIONAL HOSPITAL             704 HOSPITAL DRIVE
# 120      SAINT THOMAS HICKMAN HOSPITAL           135 EAST SWAN STREET
# 121      LYNN COUNTY HOSPITAL DISTRICT           2600 LOCKWOOD STREET
# 122            FLEMING COUNTY HOSPITAL            55 FOUNDATION DRIVE
# 123              AD HOSPITAL EAST, LLC  12950 EAST FREEWAY, SUITE 100
#
#               City_x     County_Name Phone Number_x  \
# 0             SHELBY           TOOLE   406 434-3200
# ...

# %% [markdown]
# instal some libary such as BeautifulSoup4 and geopy

# %%
# !pip install BeautifulSoup4
# !pip install geopy

# %% [markdown]
# #### imort some libary for visualization purpose

# %%
import requests
import folium 
import matplotlib.cm as cm
import matplotlib.colors as colors
import json

from urllib.request import urlopen
from geopy.geocoders import Nominatim 
from pandas.io.json import json_normalize
from sklearn.cluster import KMeans
from bs4 import BeautifulSoup

# %%
user_wish = with_lat_long[with_lat_long['Hospital_Type'].str.contains('Critical Access Hospitals')].reset_index(drop=True)
user_wish.head(116)
# Out:
#                       Facility Name_x                 Address_x  \
# 0               MARIAS MEDICAL CENTER              640 PARK AVE
# 1      BEAR VALLEY COMMUNITY HOSPITAL          41870 GARSTIN DR
# 2             KEEFE MEMORIAL HOSPITAL            602 N 6TH W ST
# 3   SANFORD CLEAR LAKE MEDICAL CENTER    701 THIRD AVENUE SOUTH
# 4   PIONEER MEMORIAL HOSPITAL HEPPNER       564 E PIONEER DRIVE
# ..                                ...                       ...
# 92     AVERA FLANDREAU HOSPITAL - CAH  214 NORTH PRAIRIE STREET
# 93           DIMMIT REGIONAL HOSPITAL        704 HOSPITAL DRIVE
# 94      SAINT THOMAS HICKMAN HOSPITAL      135 EAST SWAN STREET
# 95      LYNN COUNTY HOSPITAL DISTRICT      2600 LOCKWOOD STREET
# 96            FLEMING COUNTY HOSPITAL       55 FOUNDATION DRIVE
#
#              City_x     County_Name Phone Number_x  \
# 0            SHELBY           TOOLE   406 434-3200
# 1     BIG BEAR LAKE  SAN BERNARDINO   909 866-6501
# ...

# %% [markdown]
# #### enter your four square credential

# %%
CLIENT_ID = 'ZUWOAQTQEIPGE0YB0RCGUZFEFT5QR13XGJWR0IA3RDWLEU14' # your Foursquare ID
CLIENT_SECRET = 'EB44FEKX5WFX05JEIWJKHG2ZFSMUKLOOECTPNRVYJDTXUCMS' # your Foursquare Secret
ACCESS_TOKEN = 'ZXF0CRQEV0YSULND1TMZVE0YY3LVNVA5A1T5XWBJBICDAA4B' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZUWOAQTQEIPGE0YB0RCGUZFEFT5QR13XGJWR0IA3RDWLEU14
# CLIENT_SECRET:EB44FEKX5WFX05JEIWJKHG2ZFSMUKLOOECTPNRVYJDTXUCMS

# %% [markdown]
# now explore the first area where hospital type Critical Access Hospitals to explore the first are useuser_wish.loc[0,'latitude']

# %%
latitude = user_wish.loc[0, 'Latitude'] 
longitude = user_wish.loc[0, 'Longitude'] 
print(latitude, longitude)
# Out:
# 40.7149555 -74.0153365

# %%
search_query = 'hospital search okay'
radius = 500
print(search_query + ' .... OK!')
# Out:
# hospital search okay .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id=ZUWOAQTQEIPGE0YB0RCGUZFEFT5QR13XGJWR0IA3RDWLEU14&client_secret=EB44FEKX5WFX05JEIWJKHG2ZFSMUKLOOECTPNRVYJDTXUCMS&ll=40.7149555,-74.0153365&oauth_token=ZXF0CRQEV0YSULND1TMZVE0YY3LVNVA5A1T5XWBJBICDAA4B&v=20180604&query=Italian&radius=500&limit=30'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ZUWOAQTQEIPGE0YB0RCGUZFEFT5QR13XGJWR0IA3RDWLEU14&client_secret=EB44FEKX5WFX05JEIWJKHG2ZFSMUKLOOECTPNRVYJDTXUCMS&ll=40.7149555,-74.0153365&oauth_token=ZXF0CRQEV0YSULND1TMZVE0YY3LVNVA5A1T5XWBJBICDAA4B&v=20180604&query=Italian&radius=500&limit=30'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                             name  \
# 0  4fa862b3e4b0ebff2f749f06        Harry's Italian Pizza Bar
# 1  4f3232e219836c91c7bfde94  Conca Cucina Italian Restaurant
# 2  3fd66200f964a520f4e41ee3                             Ecco
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1607985313    False
# 1  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1607985313    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1607985313    False
#
#   location.address  location.lat  location.lng  \
# 0    225 Murray St     40.715218    -74.014739
# 1    63 W Broadway     40.714484    -74.009806
# 2  124 Chambers St     40.715337    -74.008848
#
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

# %%
dataframe_filtered
# Out:
#            categories        lat        lng  \
# 0         Pizza Place  40.715218 -74.014739
# 1                Food  40.714484 -74.009806
# 2  Italian Restaurant  40.715337 -74.008848
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.71521779064671...        58      10282  US
# 1  [{'label': 'display', 'lat': 40.71448400000000...       469      10007  US
# 2  [{'label': 'display', 'lat': 40.71533713859952...       549      10007  US
#
#        city state        country                  crossStreet
# 0  New York    NY  United States                          NaN
# 1  New York    NY  United States                          NaN
# 2  New York    NY  United States  btwn Church St & W Broadway

# %%
dataframe_filtered.categories
# Out:
# 0           Pizza Place
# 1                  Food
# 2    Italian Restaurant
# Name: categories, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
